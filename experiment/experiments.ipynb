# %%
import pandas as pd

# %%
data=pd.read_csv("/home/rahul/mlops/experiment/data/gemstone.csv")

# %%
data.head(2)
# Out:
#       id  carat    cut color clarity  depth  table     x     y     z  price
# 0  87141   0.32  Ideal     G    VVS2   61.4   57.0  4.42  4.37  2.70    936
# 1  69475   0.73  Ideal     F     VS2   62.1   57.0  5.76  5.79  3.59   2846

# %%
data["color"].value_counts()
# Out:
# color
# G    33325
# E    26934
# F    25725
# H    23051
# D    18234
# I    13096
# J     4814
# Name: count, dtype: int64

# %%
data.sample(10)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 84407   191139   0.90  Very Good     I    VVS2   62.9   58.0  6.08  6.17
# 104373   22267   0.30    Premium     E     VS2   61.0   59.0  4.28  4.33
# 95194     8773   0.50  Very Good     E     VS1   62.9   57.0  5.06  5.11
# 1324     24479   0.33      Ideal     H    VVS2   61.4   57.0  4.48  4.45
# 34447   162616   1.03      Ideal     F     SI2   62.0   56.0  6.45  6.48
# 126370   88070   0.56  Very Good     I    VVS1   61.8   55.1  5.28  5.32
# 143104  144011   1.08      Ideal     E     SI2   60.4   54.0  6.68  6.72
# 11881   115036   1.04      Ideal     H     SI1   62.3   56.0  6.50  6.46
# 40672     1439   1.03  Very Good     H     VS2   63.0   56.0  6.40  6.45
# 112004   60753   0.53      Ideal     H     VS2   61.2   56.0  5.21  5.25
#
#            z  price
# 84407   3.85   3798
# 104373  2.63    658
# 95194   3.20   1724
# 1324    2.74    666
# 34447   4.01   4698
# 126370  3.28   1698
# 143104  4.05   5400
# 11881   4.04   4333
# 40672   4.04   5469
# 112004  3.20   1401

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.size
# Out:
# 1596969

# %%
data.shape
# Out:
# (145179, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145179 entries, 0 to 145178
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       145179 non-null  int64
#  1   carat    145179 non-null  float64
#  2   cut      145179 non-null  object
#  3   color    145179 non-null  object
#  4   clarity  145179 non-null  object
#  5   depth    145179 non-null  float64
#  6   table    145179 non-null  float64
#  7   x        145179 non-null  float64
#  8   y        145179 non-null  float64
#  9   z        145179 non-null  float64
#  10  price    145179 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 12.2+ MB

# %%
data.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
data.drop(labels=["id"],axis=1,inplace=True)

# %%
data
# Out:
#         carat        cut color clarity  depth  table     x     y     z  price
# 0        0.32      Ideal     G    VVS2   61.4   57.0  4.42  4.37  2.70    936
# 1        0.73      Ideal     F     VS2   62.1   57.0  5.76  5.79  3.59   2846
# 2        1.02      Ideal     J     SI2   60.3   56.0  6.58  6.57  3.97   3104
# 3        0.41       Good     J     VS2   63.4   54.4  4.72  4.75  3.00    637
# 4        1.51      Ideal     G     VS1   62.2   56.0  7.31  7.40  4.57  11605
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 145174   1.51  Very Good     I     SI1   63.2   56.0  7.26  7.30  4.59   8288
# 145175   0.31      Ideal     D     SI2   61.4   56.0  4.39  4.37  2.69    568
# 145176   0.30       Good     D     SI1   63.1   58.0  4.27  4.25  2.69    756
# 145177   0.90      Ideal     I     VS1   61.9   56.0  6.18  6.22  3.84   3334
# 145178   0.80      Ideal     E     SI1   62.5   57.0  5.96  5.99  3.73   3447
#
# [145179 rows x 10 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145179 entries, 0 to 145178
# Data columns (total 10 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    145179 non-null  float64
#  1   cut      145179 non-null  object
#  2   color    145179 non-null  object
#  3   clarity  145179 non-null  object
#  4   depth    145179 non-null  float64
#  5   table    145179 non-null  float64
#  6   x        145179 non-null  float64
#  7   y        145179 non-null  float64
#  8   z        145179 non-null  float64
#  9   price    145179 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 11.1+ MB

# %%
cat_columns=data.columns[data.dtypes=="object"]

# %%
num_columns=data.columns[data.dtypes!="object"]

# %%
data[num_columns].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  145179.0     0.790210     0.462920    0.2    0.40     0.70     1.03
# depth  145179.0    61.820518     1.082570   53.1   61.30    61.90    62.40
# table  145179.0    57.225191     1.919658   49.0   56.00    57.00    58.00
# x      145179.0     5.714056     1.109458    0.0    4.70     5.70     6.51
# y      145179.0     5.718908     1.102379    0.0    4.71     5.72     6.51
# z      145179.0     3.533472     0.689938    0.0    2.90     3.53     4.03
# price  145179.0  3968.182554  4038.738745  326.0  951.00  2394.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
data[cat_columns]
# Out:
#               cut color clarity
# 0           Ideal     G    VVS2
# 1           Ideal     F     VS2
# 2           Ideal     J     SI2
# 3            Good     J     VS2
# 4           Ideal     G     VS1
# ...           ...   ...     ...
# 145174  Very Good     I     SI1
# 145175      Ideal     D     SI2
# 145176       Good     D     SI1
# 145177      Ideal     I     VS1
# 145178      Ideal     E     SI1
#
# [145179 rows x 3 columns]

# %%
for col in cat_columns:
    print(data[col].value_counts())
    print(f"here is the total count:{len(data[col].value_counts())}")
    print("=======================")
# Out:
# cut
# Ideal        69410
# Premium      37374
# Very Good    28133
# Good          8773
# Fair          1489
# Name: count, dtype: int64
# here is the total count:5
# =======================
# color
# G    33325
# E    26934
# F    25725
# H    23051
# D    18234
# I    13096
# J     4814
# Name: count, dtype: int64
# here is the total count:7
# =======================
# clarity
# SI1     39926
# VS2     36034
# VS1     22946
# SI2     22817
# VVS2    11839
# VVS1     8112
# IF       3115
# I1        390
# Name: count, dtype: int64
# here is the total count:8
# =======================

# %%
data[num_columns]
# Out:
#         carat  depth  table     x     y     z  price
# 0        0.32   61.4   57.0  4.42  4.37  2.70    936
# 1        0.73   62.1   57.0  5.76  5.79  3.59   2846
# 2        1.02   60.3   56.0  6.58  6.57  3.97   3104
# 3        0.41   63.4   54.4  4.72  4.75  3.00    637
# 4        1.51   62.2   56.0  7.31  7.40  4.57  11605
# ...       ...    ...    ...   ...   ...   ...    ...
# 145174   1.51   63.2   56.0  7.26  7.30  4.59   8288
# 145175   0.31   61.4   56.0  4.39  4.37  2.69    568
# 145176   0.30   63.1   58.0  4.27  4.25  2.69    756
# 145177   0.90   61.9   56.0  6.18  6.22  3.84   3334
# 145178   0.80   62.5   57.0  5.96  5.99  3.73   3447
#
# [145179 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))

for col in num_columns:
    sns.histplot(data=data,x=col,kde=True)
    print("\n")
    plt.show()

# %%
sns.heatmap(data[num_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
data[cat_columns]
# Out:
#               cut color clarity
# 0           Ideal     G    VVS2
# 1           Ideal     F     VS2
# 2           Ideal     J     SI2
# 3            Good     J     VS2
# 4           Ideal     G     VS1
# ...           ...   ...     ...
# 145174  Very Good     I     SI1
# 145175      Ideal     D     SI2
# 145176       Good     D     SI1
# 145177      Ideal     I     VS1
# 145178      Ideal     E     SI1
#
# [145179 rows x 3 columns]

# %%
# it is a oridinal encoding
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
data["cut"]=data["cut"].map(cut_map)
data["clarity"]=data["clarity"].map(clarity_map)
data["color"]=data["color"].map(color_map)

# %%
data
# Out:
#         carat  cut  color  clarity  depth  table     x     y     z  price
# 0        0.32    5      4        6   61.4   57.0  4.42  4.37  2.70    936
# 1        0.73    5      3        4   62.1   57.0  5.76  5.79  3.59   2846
# 2        1.02    5      7        2   60.3   56.0  6.58  6.57  3.97   3104
# 3        0.41    2      7        4   63.4   54.4  4.72  4.75  3.00    637
# 4        1.51    5      4        5   62.2   56.0  7.31  7.40  4.57  11605
# ...       ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 145174   1.51    3      6        3   63.2   56.0  7.26  7.30  4.59   8288
# 145175   0.31    5      1        2   61.4   56.0  4.39  4.37  2.69    568
# 145176   0.30    2      1        3   63.1   58.0  4.27  4.25  2.69    756
# 145177   0.90    5      6        5   61.9   56.0  6.18  6.22  3.84   3334
# 145178   0.80    5      2        3   62.5   57.0  5.96  5.99  3.73   3447
#
# [145179 rows x 10 columns]

# %%
import pandas as pd
data=pd.read_csv("/home/rahul/mlops/artifacts/train.csv")

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
data.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
X=data.drop(labels=["id","price"],axis=1)
y=data["price"]

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        0.32      Ideal     G    VVS2   61.4   57.0  4.42  4.37  2.70
# 1        0.73      Ideal     F     VS2   62.1   57.0  5.76  5.79  3.59
# 2        1.02      Ideal     J     SI2   60.3   56.0  6.58  6.57  3.97
# 3        0.41       Good     J     VS2   63.4   54.4  4.72  4.75  3.00
# 4        1.51      Ideal     G     VS1   62.2   56.0  7.31  7.40  4.57
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 145174   1.51  Very Good     I     SI1   63.2   56.0  7.26  7.30  4.59
# 145175   0.31      Ideal     D     SI2   61.4   56.0  4.39  4.37  2.69
# 145176   0.30       Good     D     SI1   63.1   58.0  4.27  4.25  2.69
# 145177   0.90      Ideal     I     VS1   61.9   56.0  6.18  6.22  3.84
# 145178   0.80      Ideal     E     SI1   62.5   57.0  5.96  5.99  3.73
#
# [145179 rows x 9 columns]

# %%
y
# Out:
# 0           936
# 1          2846
# 2          3104
# 3           637
# 4         11605
#           ...
# 145174     8288
# 145175      568
# 145176      756
# 145177     3334
# 145178     3447
# Name: price, Length: 145179, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145179 entries, 0 to 145178
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   carat    145179 non-null  float64
#  1   cut      145179 non-null  object
#  2   color    145179 non-null  object
#  3   clarity  145179 non-null  object
#  4   depth    145179 non-null  float64
#  5   table    145179 non-null  float64
#  6   x        145179 non-null  float64
#  7   y        145179 non-null  float64
#  8   z        145179 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 10.0+ MB

# %%
X.select_dtypes(include="object")
# Out:
#               cut color clarity
# 0           Ideal     G    VVS2
# 1           Ideal     F     VS2
# 2           Ideal     J     SI2
# 3            Good     J     VS2
# 4           Ideal     G     VS1
# ...           ...   ...     ...
# 145174  Very Good     I     SI1
# 145175      Ideal     D     SI2
# 145176       Good     D     SI1
# 145177      Ideal     I     VS1
# 145178      Ideal     E     SI1
#
# [145179 rows x 3 columns]

# %%
X.select_dtypes(exclude="object")
# Out:
#         carat  depth  table     x     y     z
# 0        0.32   61.4   57.0  4.42  4.37  2.70
# 1        0.73   62.1   57.0  5.76  5.79  3.59
# 2        1.02   60.3   56.0  6.58  6.57  3.97
# 3        0.41   63.4   54.4  4.72  4.75  3.00
# 4        1.51   62.2   56.0  7.31  7.40  4.57
# ...       ...    ...    ...   ...   ...   ...
# 145174   1.51   63.2   56.0  7.26  7.30  4.59
# 145175   0.31   61.4   56.0  4.39  4.37  2.69
# 145176   0.30   63.1   58.0  4.27  4.25  2.69
# 145177   0.90   61.9   56.0  6.18  6.22  3.84
# 145178   0.80   62.5   57.0  5.96  5.99  3.73
#
# [145179 rows x 6 columns]

# %%
cat_cols=X.select_dtypes(include="object").columns

num_cols=X.select_dtypes(exclude="object").columns

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
num_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
X.select_dtypes(include="object").head()
# Out:
#      cut color clarity
# 0  Ideal     G    VVS2
# 1  Ideal     F     VS2
# 2  Ideal     J     SI2
# 3   Good     J     VS2
# 4  Ideal     G     VS1

# %%
X["clarity"].value_counts()
# Out:
# clarity
# SI1     39926
# VS2     36034
# VS1     22946
# SI2     22817
# VVS2    11839
# VVS1     8112
# IF       3115
# I1        390
# Name: count, dtype: int64

# %%
cut_categories = ['Fair', 'Good', 'Very Good','Premium','Ideal']
color_categories = ['D', 'E', 'F', 'G', 'H', 'I', 'J']
clarity_categories = ['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF']

# %%
num_pipeline=Pipeline(
    steps=[
        ("imputer",SimpleImputer()),
        ("scaler",StandardScaler())
    ]
)

# %%
cat_pipeline=Pipeline(

    steps=[
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("ordinalencoder",OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))

    ]
)

# %%
num_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
preprocessor=ColumnTransformer(

    [
        ("num_pipeline",num_pipeline,num_cols),
        ("cat_pipeline",cat_pipeline,cat_cols)
    ]
)

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        0.32      Ideal     G    VVS2   61.4   57.0  4.42  4.37  2.70
# 1        0.73      Ideal     F     VS2   62.1   57.0  5.76  5.79  3.59
# 2        1.02      Ideal     J     SI2   60.3   56.0  6.58  6.57  3.97
# 3        0.41       Good     J     VS2   63.4   54.4  4.72  4.75  3.00
# 4        1.51      Ideal     G     VS1   62.2   56.0  7.31  7.40  4.57
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 145174   1.51  Very Good     I     SI1   63.2   56.0  7.26  7.30  4.59
# 145175   0.31      Ideal     D     SI2   61.4   56.0  4.39  4.37  2.69
# 145176   0.30       Good     D     SI1   63.1   58.0  4.27  4.25  2.69
# 145177   0.90      Ideal     I     VS1   61.9   56.0  6.18  6.22  3.84
# 145178   0.80      Ideal     E     SI1   62.5   57.0  5.96  5.99  3.73
#
# [145179 rows x 9 columns]

# %%
y
# Out:
# 0           936
# 1          2846
# 2          3104
# 3           637
# 4         11605
#           ...
# 145174     8288
# 145175      568
# 145176      756
# 145177     3334
# 145178     3447
# Name: price, Length: 145179, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30, random_state=42)

# %%
X_test.shape
# Out:
# (43554, 9)

# %%
y_train.head()
# Out:
# 57800      478
# 82400     1196
# 52609      674
# 58347     9354
# 122095     485
# Name: price, dtype: int64

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-1.16534826,  0.16590018, -1.15937112, ...,  4.        ,
#          4.        ,  6.        ],
#        [-0.81973069, -0.01909881, -0.63790827, ...,  4.        ,
#          2.        ,  5.        ],
#        [-1.05734277,  0.25839967, -0.63790827, ...,  4.        ,
#          3.        ,  5.        ],
#        ...,
#        [-0.77652849, -1.40659123, -0.63790827, ...,  4.        ,
#          6.        ,  3.        ],
#        [ 0.49793629,  0.16590018, -0.11644541, ...,  4.        ,
#          3.        ,  3.        ],
#        [ 0.56273958, -3.07158213,  1.969406  , ...,  3.        ,
#          1.        ,  2.        ]])

# %%
preprocessor.transform(X_test)
# Out:
# array([[ 0.02271213,  0.44339866, -0.63790827, ...,  4.        ,
#          2.        ,  2.        ],
#        [-0.84133179,  1.09089512, -2.20229683, ...,  4.        ,
#          0.        ,  1.        ],
#        [-0.90613508, -1.49909072,  2.49086885, ...,  2.        ,
#          2.        ,  6.        ],
#        ...,
#        [-1.01414057,  0.16590018, -0.11644541, ...,  4.        ,
#          4.        ,  6.        ],
#        [ 0.26032421,  0.35089916, -0.63790827, ...,  4.        ,
#          5.        ,  3.        ],
#        [-0.81973069,  0.62839765,  0.92648029, ...,  3.        ,
#          4.        ,  6.        ]])

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num_pipeline__carat', 'num_pipeline__depth',
#        'num_pipeline__table', 'num_pipeline__x', 'num_pipeline__y',
#        'num_pipeline__z', 'cat_pipeline__cut', 'cat_pipeline__color',
#        'cat_pipeline__clarity'], dtype=object)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
X_train
# Out:
#         num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 -1.165348             0.165900            -1.159371
# 1                 -0.819731            -0.019099            -0.637908
# 2                 -1.057343             0.258400            -0.637908
# 3                  1.124368            -0.389097            -0.116445
# 4                 -1.186949            -1.129093             1.969406
# ...                     ...                  ...                  ...
# 101620            -0.560518             0.350899            -0.637908
# 101621            -0.193299             1.830891            -0.116445
# 101622            -0.776528            -1.406591            -0.637908
# 101623             0.497936             0.165900            -0.116445
# 101624             0.562740            -3.071582             1.969406
#
#         num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0             -1.506422        -1.484439        -1.477898                4.0
# 1             -0.839697        -0.822411        -0.812867                4.0
# 2             -1.326226        -1.303062        -1.289955                4.0
# 3              1.169489         1.127397         1.124397                4.0
# 4             -1.551471        -1.529783        -1.593556                1.0
# ...                 ...              ...              ...                ...
# 101620        -0.461285        -0.441518        -0.436980                4.0
# 101621        -0.100893        -0.078763         0.054565                1.0
# 101622        -0.731579        -0.713585        -0.812867                4.0
# 101623         0.664940         0.646747         0.661767                4.0
# 101624         0.908204         0.927882         0.560567                3.0
#
#         cat_pipeline__color  cat_pipeline__clarity
# 0                       4.0                    6.0
# 1                       2.0                    5.0
# 2                       3.0                    5.0
# 3                       3.0                    4.0
# 4                       1.0                    5.0
# ...                     ...                    ...
# 101620                  3.0                    4.0
# 101621                  0.0                    2.0
# 101622                  6.0                    3.0
# 101623                  3.0                    3.0
# 101624                  1.0                    2.0
#
# [101625 rows x 9 columns]

# %%
X_test
# Out:
#        num_pipeline__carat  num_pipeline__depth  num_pipeline__table  \
# 0                 0.022712             0.443399            -0.637908
# 1                -0.841332             1.090895            -2.202297
# 2                -0.906135            -1.499091             2.490869
# 3                 0.800352             0.535898            -0.116445
# 4                 0.713947            -0.296597            -0.637908
# ...                    ...                  ...                  ...
# 43549             0.627543            -0.759095             0.405017
# 43550            -1.057343             0.998396            -0.637908
# 43551            -1.014141             0.165900            -0.116445
# 43552             0.260324             0.350899            -0.637908
# 43553            -0.819731             0.628398             0.926480
#
#        num_pipeline__x  num_pipeline__y  num_pipeline__z  cat_pipeline__cut  \
# 0             0.214450         0.229578         0.271423                4.0
# 1            -0.893756        -0.894962        -0.798410                4.0
# 2            -0.902766        -0.976582        -1.044182                2.0
# 3             0.908204         0.946020         0.936454                4.0
# 4             0.890185         0.927882         0.864168                4.0
# ...                ...              ...              ...                ...
# 43549         0.800087         0.837193         0.748510                2.0
# 43550        -1.290187        -1.284924        -1.217669                4.0
# 43551        -1.191079        -1.212373        -1.174297                4.0
# 43552         0.430685         0.456300         0.473823                4.0
# 43553        -0.893756        -0.940307        -0.856239                3.0
#
#        cat_pipeline__color  cat_pipeline__clarity
# 0                      2.0                    2.0
# 1                      0.0                    1.0
# 2                      2.0                    6.0
# 3                      6.0                    4.0
# 4                      2.0                    2.0
# ...                    ...                    ...
# 43549                  1.0                    2.0
# 43550                  2.0                    3.0
# 43551                  4.0                    6.0
# 43552                  5.0                    3.0
# 43553                  4.0                    6.0
#
# [43554 rows x 9 columns]

# %% [markdown]
# # model training

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
models={

    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
    'Randomforest':RandomForestRegressor(),
    'xgboost':XGBRegressor()

}

# %%
trained_model_list=[]
model_list=[]
r2_list=[]

# %%
list(models)
# Out:
# ['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'Randomforest', 'xgboost']

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    print(model)
# Out:
# LinearRegression()
# Lasso()
# Ridge()
# ElasticNet()
# RandomForestRegressor()
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
models.keys()
# Out:
# dict_keys(['LinearRegression', 'Lasso', 'Ridge', 'Elasticnet', 'Randomforest', 'xgboost'])

# %%
list(models.values())[1]
# Out:
# Lasso()

# %%
def evaluate_model(true,pred):
    r2=r2_score(true,pred)
    mae=mean_absolute_error(true,pred)
    mse=mean_squared_error(true,pred)

    return mae, mse,r2

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    
    model.fit(X_train,y_train)

    #make_prediction
    y_pred=model.predict(X_test)

    #this is for the validaiton
    MAE,MSE,R2=evaluate_model(y_test,y_pred)


    print("model training performance",model)
    print("MSE:", MSE)
    print("MAE:",MAE)
    print("R2 SCORE:",R2)

    r2_list.append(R2)

    print("="*40)
    print("\n")
# Out:
# model training performance LinearRegression()
# MSE: 1036988.9195732354
# MAE: 677.4867866402202
# R2 SCORE: 0.9360075848068807
# ========================================
#
#
# model training performance Lasso()
# MSE: 1036835.8540156499
# MAE: 678.6887023277958
# R2 SCORE: 0.9360170304571938
# ========================================
#
#
# model training performance Ridge()
# MSE: 1036982.6223224594
# MAE: 677.526500410231
# R2 SCORE: 0.9360079734091875
# ========================================
#
#
# model training performance ElasticNet()
# MSE: 2266028.4582641404
# MAE: 1051.632292364015
# R2 SCORE: 0.8601637575835045
# ========================================
#
#
# model training performance RandomForestRegressor()
# MSE: 384576.12663961895
# MAE: 315.3139788043633
# R2 SCORE: 0.9762678706543826
# ========================================
#
#
# model training performance XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)
# MSE: 354229.75310882216
# MAE: 302.62358355737837
# R2 SCORE: 0.9781405403598481
# ========================================

# %%
r2_list
# Out:
# [0.9360075848068807,
#  0.9360170304571938,
#  0.9360079734091875,
#  0.8601637575835045,
#  0.9762678706543826,
#  0.9781405403598481]

# %%
max(r2_list)
# Out:
# 0.9781405403598481

# %%
import logging
import os
from datetime import datetime

# %%
LOG_FILE=f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

log_path=os.path.join(os.getcwd(),"logs")

os.makedirs(log_path,exist_ok=True)

LOG_FILEPATH=os.path.join(log_path,LOG_FILE)

# %%
LOG_FILEPATH
# Out:
# '/config/workspace/experiment/logs/01_10_2024_15_49_44.log'

# %%
logging.basicConfig(level=logging.INFO, 
                    filename=LOG_FILEPATH,
                    format="[%(asctime)s] %(lineno)d %(name)s - %(levelname)s - %(message)s"
                    
)

# %%
logging.info("this is my test log")
